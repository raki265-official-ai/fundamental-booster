# %% [markdown]
# # PYTHON PROJECT

# %% [markdown]
# # 1-personal tracker

# %%
name=str(input("enter your name:"))
income=int(input("enter your income:"))
rent=int(input("enter your rent amount:"))
food=int(input("enter your food amount:"))
travel=int(input("enter your travel expenses:"))
total=rent+food+travel
print("total=",sum)
savings=income-total
print("savings:",savings)
# Out:
# enter your name: rakesh
# enter your income: 50000
# enter your rent amount: 8000
# enter your food amount: 5000
# enter your travel expenses: 10000
# total= 23000
# savings: 27000

# %%
sum=rent+food+travel
print("total=",sum)
# Out:
# total= 23000

# %% [markdown]
# # 2-bmi calucalator

# %%
name=str(input("enter your name:"))
weight=float(input("enter your weight:"))
height=float(input("enter your height:"))
bmi=weight/height
print("bmi:",bmi)
# Out:
# enter your name: raki
# enter your weight: 88
# enter your height: 172
# bmi: 0.5116279069767442

# %% [markdown]
# # 3-student grade

# %%
name=str(input("enter your name:"))
maths=float(input("maths marks:"))
science=float(input("science marks:"))
english=float(input("english markss:"))
total=maths+science+english
print("total:",total)
average=total/3
print("average:",average)
# Out:
# enter your name: rakesh
# maths marks: 89
# science marks: 65
# english markss: 95
# total: 249.0
# average: 83.0
