# %%
print("raki")
# Out:
# raki

# %%
print("raki")
# Out:
# raki

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
a=50
b=80.90
c="scinece"
print(a)
print(b)
print(c)
# Out:
# 50
# 80.9
# scinece

# %%
_a=10
b="data analyst"
x_=30.90
print(_a)
print(type(_a))
print(b)
print(type(b))
print(x_)
print(type(x_))
# Out:
# 10
# <class 'int'>
# data analyst
# <class 'str'>
# 30.9
# <class 'float'>

# %%
a,b,c,d,e=20,30,40,"photoshop",70.34
x,y,z=2,"soni",5
print(b)
print(a)
print("####")
print(y)
print(x)
# Out:
# 30
# 20
# ####
# soni
# 2

# %%
name=str(input("enter your name:"))
num=int(input("entrt your nub:"))
add=str(input("enter yout add:"))
perc=float(input("enter your%:"))
print(perc,"%")
# Out:
# enter your name: raki
# entrt your nub: 8096871249
# enter yout add: maa khodiyar residency
# enter your%: 89.1
# 89.1 %

# %%
age=int(input("enter your age"))
height=float(input("enter your height in meters: "))
print("your are",age,"years old and",height,"meters tall.")
# Out:
# enter your age 26
# enter your height in meters:  1.02
# your are 26 years old and 1.02 meters tall.

# %%
salary=int(input("enter yout salary"))
# Out:
# enter yout salary 60000

# %%
movie=str(input("enter your movie"))
# Out:
# enter your movie bahhbali

# %%
education=str(input("instititute"))
# Out:
# instititute r&w education

# %%
education=str(input("instititute"))
# Out:
# instititute r&w education

# %%
cars=50
miles=43.6
name="carry"
print(cars)
print(miles)
print(name)
# Out:
# 50
# 43.6
# carry

# %%
cars=50
miles=43.6
name="carry"
print(cars)
print(miles)
print(name)
# Out:
# 50
# 43.6
# carry

# %%
list =["cars" ,786,2.23,"toyota",70.2]
tinylist=[123,"camry"]
print(list[1])
# Out:
# 786

# %%
list=["cars",786,2.23,"toyota",70.2]
tinylist=[123,"camry"]
print (list)
print (list[0])
print(list[1:3])
print(list[2:])
print (tinylist *2)
print ("list" +" tinylyst")
# Out:
# ['cars', 786, 2.23, 'toyota', 70.2]
# cars
# [786, 2.23]
# [2.23, 'toyota', 70.2]
# [123, 'camry', 123, 'camry']
# list tinylyst

# %%
list=["bikes",265,2.65,"pulsar",786]
under=(123,"raki")
print list[1]
# Out:
#   Cell In[24], line 3
#     print list[1]
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
rakesh=50
soniya=70
print(rakesh+soniya)
# Out:
# 120

# %%
rakesh=soniya
print(rakesh)
# Out:
# 70

# %%
rakesh-soniya
print(rakesh)
# Out:
# 70

# %%
print("*******")
# Out:
# *******

# %%
print('****')
# Out:
# ****

# %%
habit="gambling"
del habit
print(habit)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 habit="gambling"
#       2 del habit
# ----> 3 print(habit)
#
# NameError: name 'habit' is not defined

# %%
result=1+2+3*5+2/4*2
print(result)
# Out:
# 19.0

# %%
course = "Python"
print(type(course))

# Output:
# <class 'str'>
# Out:
# <class 'str'>

# %%
course = "Python"
print(id(course))

# Output:
# 4305393408
# Out:
# 1896942669664

# %%
str1="hello"
str2="world"
print(str1+str2)
# Out:
# helloworld

# %%
rakesh="ha"
print(rakesh*3)
# Out:
# hahaha

# %%
text="rakesh pedduri"
print(len(text))
# Out:
# 14

# %%
text="RAKESH"
print(text.lower())
# Out:
# rakesh

# %%
text="rakesh"
print(text.upper())
# Out:
# RAKESH

# %%
text="rakesh"
print(text.capitalize())
text="rakesh"
print(text.title())
text="rakesh"
# Out:
# Rakesh
# Rakesh

# %%
text="  hello world  "
print(text.strip())
text="rakesh pedduri"
print(text.split())
text=["rakesh","peduri"]
print(' '.join(text))
# Out:
# hello world
# ['rakesh', 'pedduri']
# rakesh peduri

# %%
text="rakesh pedduri"
print(text.find('pedduri'))
print(text.find('rakesh'))
text="rakesh"
print(text.find("rakesh"))
# Out:
# 7
# 0
# 0

# %%
text="raki pedduri"
print(text.replace("pedduri","konga"))
# Out:
# raki konga

# %%
a=5
b=3
print(a-b)
# Out:
# 2
